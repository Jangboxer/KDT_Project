# %%
import pandas as pd
from konlpy.tag import Okt
from tqdm import tqdm
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from sklearn.decomposition import LatentDirichletAllocation
import pyLDAvis
from gensim import corpora
from gensim.models import LdaModel
import pyLDAvis.gensim_models as gensimvis
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns
import fontda

# %%
a=[42.6,18,20,12.6,6.8]
b=['이용후기','할인혜택','가격','디자인','기타']
df=pd.DataFrame(a)

# %%
df=df.T

# %%
df
# Out:
#       0     1     2     3    4
# 0  42.6  18.0  20.0  12.6  6.8

# %%
df.columns=b

# %%
df
# Out:
#    이용후기  할인혜택    가격   디자인   기타
# 0  42.6  18.0  20.0  12.6  6.8

# %%
fe = font_manager.FontEntry(
    fname=r'C:\Users\KDP-26-\AppData\Local\Microsoft\Windows\Fonts\TENADA.ttf', # ttf 파일이 저장되어 있는 경로
    name='TENADA')                        # 이 폰트의 원하는 이름 설정
font_manager.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 20, 'font.family': 'TENADA'}) # 폰트 설정
explode = (0.1, 0, 0, 0, 0)
# 파이그래프 그리기
plt.figure(figsize=(8, 8))
plt.pie(df.iloc[0], labels=df.columns, autopct='%1.1f%%', startangle=-10, colors=sns.color_palette('pastel'),explode=explode)
from matplotlib import font_manager

# 차트 제목 추가
plt.title('비슷한제품 구매시 고려요인',size=30)

# 그래프 보이기
plt.show()
